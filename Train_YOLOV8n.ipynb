# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.11 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.8/78.2 GB disk)

# %% [markdown]
# ## Predict trước khi train

# %%
# !unzip /content/drive/MyDrive/RoadSignYOLO.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: RoadSignYOLO/train/images/IN_20240319_20_07_35_Pro24.jpg
#   inflating: RoadSignYOLO/train/images/IN_20240319_20_07_35_Pro25.jpg
#   inflating: RoadSignYOLO/train/images/IN_20240319_20_07_35_Pro29.jpg
#   inflating: RoadSignYOLO/train/images/IN_20240319_20_07_35_Pro3.jpg
#   inflating: RoadSignYOLO/train/images/IN_20240319_20_07_35_Pro30.jpg
#   inflating: RoadSignYOLO/train/images/IN_20240319_20_07_35_Pro33.jpg
#   inflating: RoadSignYOLO/train/images/IN_20240319_20_07_35_Pro34.jpg
#   inflating: RoadSignYOLO/train/images/IN_20240319_20_07_35_Pro35.jpg
#   inflating: RoadSignYOLO/train/images/IN_20240319_20_07_35_Pro36.jpg
#   inflating: RoadSignYOLO/train/images/IN_20240319_20_07_35_Pro37.jpg
#   inflating: RoadSignYOLO/train/images/IN_20240319_20_07_35_Pro38.jpg
#   inflating: RoadSignYOLO/train/images/IN_20240319_20_07_35_Pro39.jpg
#   inflating: RoadSignYOLO/train/images/IN_20240319_20_07_35_Pro4.jpg
# ...

# %%
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO('yolov8n.pt')
# results = model('/content/Fashion/test/images/11277842862_0.png')
# results
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 127MB/s]

# %% [markdown]
# ## Load dữ liệu và training

# %%
# !yolo train model=yolov8n.pt data=/content/RoadSignYOLO/data.yaml epochs=500 imgsz=640 translate=0.1 fliplr=0.0 mixup=0.05
# Out:
# Ultralytics YOLOv8.2.11 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !unzip /content/drive/MyDrive/test.zip
# Out:
# Archive:  /content/drive/MyDrive/test.zip
#    creating: test/
#    creating: test/images/
#   inflating: test/images/IN_20240319_19_45_59_Pro12.jpg
#   inflating: test/images/IN_20240319_19_45_59_Pro24.jpg
#   inflating: test/images/IN_20240319_19_45_59_Pro64.jpg
#   inflating: test/images/IN_20240319_19_45_59_Pro87.jpg
#   inflating: test/images/IN_20240319_19_50_52_Pro107.jpg
#   inflating: test/images/IN_20240319_19_50_52_Pro14.jpg
#   inflating: test/images/IN_20240319_19_50_52_Pro45.jpg
#   inflating: test/images/IN_20240319_19_52_22_Pro9.jpg
#   inflating: test/images/IN_20240319_19_55_26_Pro16.jpg
#   inflating: test/images/IN_20240319_19_58_44_Pro32.jpg
#   inflating: test/images/IN_20240319_20_01_08_Pro22.jpg
#   inflating: test/images/IN_20240319_20_01_08_Pro39.jpg
#   inflating: test/images/IN_20240319_20_03_29_Pro36.jpg
#   inflating: test/images/IN_20240319_20_03_29_Pro74.jpg
#   inflating: test/images/IN_20240319_20_03_29_Pro8.jpg
# ...

# %% [markdown]
# ## Predict sau train

# %%
model = YOLO('/content/drive/MyDrive/best.pt')
results = model('/content/test/images/IN_20240319_20_03_29_Pro36.jpg')
results
# Out:
# image 1/1 /content/test/images/IN_20240319_20_03_29_Pro36.jpg: 384x640 1 Left, 7.3ms
# Speed: 1.5ms preprocess, 7.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Left', 1: 'Right', 2: 'Stop', 3: 'Straight'}
#  obb: None
#  orig_img: array([[[ 17,  19,  19],
#          [ 16,  18,  18],
#          [ 17,  19,  19],
#          ...,
#          [189, 188, 190],
#          [189, 188, 190],
#          [188, 187, 189]],
#
#         [[ 18,  20,  20],
#          [ 18,  20,  20],
#          [ 18,  20,  20],
#          ...,
#          [191, 190, 192],
#          [192, 191, 193],
#          [191, 190, 192]],
#
#         [[ 23,  26,  24],
#          [ 22,  25,  23],
#          [ 22,  25,  23],
#          ...,
#          [191, 190, 192],
#          [189, 191, 192],
#          [189, 191, 192]],
#
#         ...,
#
# ...

# %% [markdown]
# ## Xuất model ra định dạng ONNX

# %%
# !yolo export model=/content/drive/MyDrive/best.pt format=onnx
# Out:
# Ultralytics YOLOv8.2.11 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.00GHz)
# Model summary (fused): 168 layers, 3006428 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from '/content/drive/MyDrive/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 8, 8400) (5.9 MB)
# requirements: Ultralytics requirement ['onnx>=1.12.0'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 56.9 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 9.0s, installed 1 package: ['onnx>=1.12.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.16.0 opset 17...
# ONNX: export success ✅ 10.4s, saved as '/content/drive/MyDrive/best.onnx' (11.7 MB)
#
# Export complete (12.6s)
# Results saved to /content/drive/MyDrive
# Predict:         yolo predict task=detect model=/content/drive/MyDrive/best.onnx imgsz=640
# ...
